# %% [markdown]
# # Generating Togo initial sample

# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %% [markdown]
# ## Clustered Initial Sample

# %%
from cluster_sampling import ClusterSampler

# %%
ADMIN_IDS = {
    'canton': 'canton'
}

data_path = f"/home/libe2152/optimizedsampling/0_data/admin_gdfs/togo/gdf_adm3.geojson"
gdf = gpd.read_file(data_path)
train_ids = pd.read_csv('/share/togo/splits/train_ids.csv').astype(str)
train_id_set = set(train_ids.iloc[:, 0])
gdf = gdf[gdf['id'].astype(str).isin(train_ids.iloc[:, 0])].copy()

gdf['canton'] = gdf['combined_adm_id']
gdf['prefecture'] = gdf['admin_2']
gdf['region'] = gdf['admin_1']

out_path = f'/home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling'

country_shape_file = '/home/libe2152/togo/data/shapefiles/openAfrica/Shapefiles/tgo_admbnda_adm0_inseed_itos_20210107.shp'

strata_col = 'region'
cluster_col = 'canton'

all_strata = gdf[strata_col].astype(str).unique()
n_strata = 1
print(all_strata)

np.random.seed(121212) #78910
fixed_strata = np.random.choice(all_strata, size=n_strata, replace=False)

for points_per_cluster in [10, 25]:
    sampler = ClusterSampler(gdf, id_col='id', strata_col=strata_col, cluster_col=cluster_col, ADMIN_IDS=ADMIN_IDS)
    for total_sample_size in range(500, 1100, 100):
        
        for seed in [1, 42, 123, 456, 789, 1234, 5678, 9101, 1213, 1415]:
            try:
                sampler.sample(total_sample_size, points_per_cluster, seed, fixed_strata=fixed_strata)
                sampler.save_sampled_ids(out_path)

                # Assert that all sampled ids are in train_ids
                sampled_ids_set = set(map(str, sampler.sampled_ids))
                assert sampled_ids_set.issubset(train_id_set), (
                    "Error: Some sampled IDs are not in train_ids!"
                )
                sampler.plot(country_shape_file=country_shape_file)
            except Exception as e:
                print(e)
                from IPython import embed; embed()
            sampler.reset_sample()
# Out:
# [Init] Initializing ClusterSampler...
# [Stratify] Stratifying points by column: region
# [Stratify] Unique strata found: ['savanes' 'kara' 'centrale' 'plateaux' 'maritime']
# [Init] Found 5 strata.
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 499
# Clusters: canton
# Saved 499 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_1.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_499_size_seed_1.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 500
# Clusters: canton
# Saved 500 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_42.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_500_size_seed_42.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 500
# Clusters: canton
# Saved 500 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_123.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_500_size_seed_123.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 499
# Clusters: canton
# Saved 499 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_456.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_499_size_seed_456.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 493
# Clusters: canton
# Saved 493 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_789.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_493_size_seed_789.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 492
# Clusters: canton
# Saved 492 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_1234.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_492_size_seed_1234.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 495
# Clusters: canton
# Saved 495 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_5678.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_495_size_seed_5678.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 494
# Clusters: canton
# Saved 494 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_9101.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_494_size_seed_9101.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 494
# Clusters: canton
# Saved 494 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_1213.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_494_size_seed_1213.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 500
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 500}
# [Sample] Sample sizes per stratum: {'savanes': 500}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 495
# Clusters: canton
# Saved 495 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_500_size_seed_1415.pkl
# Saved plot to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/plots/sample_region_canton_10ppc_495_size_seed_1415.png
# [Reset Sample] Clearing previous sample state...
# [Sample] Starting sampling process...
# [Determine Sample Sizes] Total desired sample size: 600
# [Determine Sample Sizes] Selected strata: ['savanes']
# [Determine Sample Sizes] Final sample size per stratum:
# {'savanes': 600}
# [Sample] Sample sizes per stratum: {'savanes': 600}
# [Sample] Processing stratum: savanes
# [Sample] Sampling complete. Total points sampled: 592
# Clusters: canton
# Saved 592 sampled IDs and metadata to /home/libe2152/optimizedsampling/0_data/initial_samples/togo/cluster_sampling/fixedstrata_savanes/sample_region_canton_10ppc_600_size_seed_1.pkl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 42
#      38     sampled_ids_set = set(map(str, sampler.sampled_ids))
#      39     assert sampled_ids_set.issubset(train_id_set), (
#      40         "Error: Some sampled IDs are not in train_ids!"
#      41     )
# ---> 42     sampler.plot(country_shape_file=country_shape_file)
#      43 except Exception as e:
#      44     print(e)
#
# File ~/optimizedsampling/2_initial_sample/cluster_sampling.py:291, in ClusterSampler.plot(self, country_shape_file, country_name, exclude_names)
#     289 def plot(self, country_shape_file, country_name=None, exclude_names=None):
#     290     """Plot and save the map of sampled points."""
# --> 291     fig, ax = plt.subplots(figsize=(12, 10))
#     292     country = gpd.read_file(country_shape_file, engine="pyogrio")
#     293     if country_name is not None:
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/pyplot.py:1776, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1631 """
#    1632 Create a figure and a set of subplots.
#    1633
#    (...)   1773
#    1774 """
#    1775 fig = figure(**fig_kw)
# -> 1776 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1777                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1778                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1779                    width_ratios=width_ratios)
#    1780 return fig, axs
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/figure.py:919, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     916     gridspec_kw['width_ratios'] = width_ratios
#     918 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 919 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                   subplot_kw=subplot_kw)
#     921 return axs
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/gridspec.py:283, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     281         subplot_kw["sharex"] = shared_with[sharex]
#     282         subplot_kw["sharey"] = shared_with[sharey]
# --> 283         axarr[row, col] = figure.add_subplot(
#     284             self[row, col], **subplot_kw)
#     286 # turn off redundant tick labeling
#     287 if sharex in ["col", "all"]:
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     766         args = tuple(map(int, str(args[0])))
#     767     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/axes/_base.py:688, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     685 self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     687 # this call may differ for non-sep axes, e.g., polar
# --> 688 self._init_axis()
#     689 if facecolor is None:
#     690     facecolor = mpl.rcParams['axes.facecolor']
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/axes/_base.py:833, in _AxesBase._init_axis(self)
#     831 self.spines.bottom.register_axis(self.xaxis)
#     832 self.spines.top.register_axis(self.xaxis)
# --> 833 self.yaxis = maxis.YAxis(self, clear=False)
#     834 self.spines.left.register_axis(self.yaxis)
#     835 self.spines.right.register_axis(self.yaxis)
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/axis.py:2610, in YAxis.__init__(self, *args, **kwargs)
#    2609 def __init__(self, *args, **kwargs):
# -> 2610     super().__init__(*args, **kwargs)
#    2611     self._init()
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/axis.py:649, in Axis.__init__(self, axes, pickradius, clear)
#     641 self.label = mtext.Text(
#     642     np.nan, np.nan,
#     643     fontsize=mpl.rcParams['axes.labelsize'],
#     644     fontweight=mpl.rcParams['axes.labelweight'],
#     645     color=mpl.rcParams['axes.labelcolor'],
#     646 )  #: The `.Text` object of the axis label.
#     648 self._set_artist_props(self.label)
# --> 649 self.offsetText = mtext.Text(np.nan, np.nan)
#     650 self._set_artist_props(self.offsetText)
#     652 self.labelpad = mpl.rcParams['axes.labelpad']
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/text.py:139, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     137 self._x, self._y = x, y
#     138 self._text = ''
# --> 139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#     142     fontproperties=fontproperties,
#     143     usetex=usetex,
#     144     parse_math=parse_math,
#     145     wrap=wrap,
#     146     verticalalignment=verticalalignment,
#     147     horizontalalignment=horizontalalignment,
#     148     multialignment=multialignment,
#     149     rotation=rotation,
#     150     transform_rotates_text=transform_rotates_text,
#     151     linespacing=linespacing,
#     152     rotation_mode=rotation_mode,
#     153     antialiased=antialiased
#     154 )
#     155 self.update(kwargs)
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/text.py:176, in Text._reset_visual_defaults(self, text, color, fontproperties, usetex, parse_math, wrap, verticalalignment, horizontalalignment, multialignment, rotation, transform_rotates_text, linespacing, rotation_mode, antialiased)
#     174 self.set_text(text)
#     175 self.set_color(mpl._val_or_rc(color, "text.color"))
# --> 176 self.set_fontproperties(fontproperties)
#     177 self.set_usetex(usetex)
#     178 self.set_parse_math(mpl._val_or_rc(parse_math, 'text.parse_math'))
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/text.py:1327, in Text.set_fontproperties(self, fp)
#    1316 def set_fontproperties(self, fp):
#    1317     """
#    1318     Set the font properties that control the text.
#    1319
#    (...)   1325         absolute path to a font file.
#    1326     """
# -> 1327     self._fontproperties = FontProperties._from_any(fp).copy()
#    1328     self.stale = True
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/font_manager.py:690, in FontProperties._from_any(cls, arg)
#     679 """
#     680 Generic constructor which can build a `.FontProperties` from any of the
#     681 following:
#    (...)    687 - a `dict`: it is passed as ``**kwargs`` to `.FontProperties`.
#     688 """
#     689 if arg is None:
# --> 690     return cls()
#     691 elif isinstance(arg, cls):
#     692     return arg
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/font_manager.py:583, in _cleanup_fontproperties_init.<locals>.wrapper(self, *args, **kwargs)
#     572     _api.warn_deprecated(
#     573         "3.10",
#     574         message="Passing family as positional argument to FontProperties() "
#    (...)    577                 "argument."
#     578     )
#     579 # Note on single string arg:
#     580 # This has been interpreted as pattern so far. We are already raising if a
#     581 # non-pattern compatible family string was given. Therefore, we do not need
#     582 # to warn for this case.
# --> 583 return init_method(self, *args, **kwargs)
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/font_manager.py:668, in FontProperties.__init__(self, family, style, variant, weight, stretch, size, fname, math_fontfamily)
#     666 self.set_file(fname)
#     667 self.set_size(size)
# --> 668 self.set_math_fontfamily(math_fontfamily)
#     669 # Treat family as a fontconfig pattern if it is the only parameter
#     670 # provided.  Even in that case, call the other setters first to set
#     671 # attributes not specified by the pattern to the rcParams defaults.
#     672 if (isinstance(family, str)
#     673         and style is None and variant is None and weight is None
#     674         and stretch is None and size is None and fname is None):
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/font_manager.py:953, in FontProperties.set_math_fontfamily(self, fontfamily)
#     935 """
#     936 Set the font family for text in math mode.
#     937
#    (...)    950 .text.Text.get_math_fontfamily
#     951 """
#     952 if fontfamily is None:
# --> 953     fontfamily = mpl.rcParams['mathtext.fontset']
#     954 else:
#     955     valid_fonts = _validators['mathtext.fontset'].valid.values()
#
# File /share/anaconda3/envs/al/lib/python3.11/site-packages/matplotlib/__init__.py:778, in RcParams.__getitem__(self, key)
#     773     except KeyError as err:
#     774         raise KeyError(
#     775             f"{key} is not a valid rc parameter (see rcParams.keys() for "
#     776             f"a list of valid parameters)") from err
# --> 778 def __getitem__(self, key):
#     779     if key in _deprecated_map:
#     780         version, alt_key, alt_val, inverse_alt = _deprecated_map[key]
#
# KeyboardInterrupt:
